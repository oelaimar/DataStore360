# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv("../data/raw/store-data.csv")

profile = ProfileReport(df, title="Data Profiling Report")

profile.to_file("../reports/rapport_profiling.html")
# Out:
# Summarize dataset:   0%|          | 0/26 [00:00<?, ?it/s, Describe variable: Segment]
# Summarize dataset:   4%|▍         | 1/26 [00:00<00:12,  1.94it/s, Describe variable: Country]
# Summarize dataset:  23%|██▎       | 6/26 [00:00<00:02,  9.84it/s, Describe variable: Product ID]
# Summarize dataset:  42%|████▏     | 11/26 [00:01<00:00, 18.66it/s, Describe variable: Sales]
# Summarize dataset:  46%|████▌     | 12/26 [00:01<00:00, 18.66it/s, Describe variable: Discount]
# Summarize dataset:  58%|█████▊    | 15/26 [00:01<00:00, 11.88it/s, Describe variable: Profit]
# Summarize dataset:  65%|██████▌   | 17/26 [00:01<00:00, 11.66it/s, Describe variable: Profit]
# 100%|██████████| 21/21 [00:01<00:00, 16.60it/s]1<00:00, 13.68it/s, Describe variable: Profit]
# Summarize dataset: 100%|██████████| 56/56 [00:03<00:00, 14.07it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:04<00:00,  4.88s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 60.02it/s]
