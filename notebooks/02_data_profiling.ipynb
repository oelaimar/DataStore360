# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv("../data/raw/store-data.csv")

profile = ProfileReport(df, title="Data Profiling Report")

profile.to_file("../reports/rapport_profiling.html")
# Out:
# Summarize dataset:   0%|          | 0/26 [00:00<?, ?it/s, Describe variable: Segment]
# Summarize dataset:  15%|█▌        | 4/26 [00:00<00:02,  9.13it/s, Describe variable: Postal Code]
# Summarize dataset:  31%|███       | 8/26 [00:00<00:01, 12.95it/s, Describe variable: Product ID]
# Summarize dataset:  46%|████▌     | 12/26 [00:01<00:00, 14.14it/s, Describe variable: Discount]
# Summarize dataset:  58%|█████▊    | 15/26 [00:01<00:00, 12.45it/s, Describe variable: Profit]
# Summarize dataset:  65%|██████▌   | 17/26 [00:01<00:00, 15.52it/s, Describe variable: Profit]
# 100%|██████████| 21/21 [00:01<00:00, 19.60it/s]
# Summarize dataset: 100%|██████████| 56/56 [00:03<00:00, 14.54it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:04<00:00,  4.91s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  5.78it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 64.93it/s]
